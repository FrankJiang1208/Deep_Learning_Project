# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
df = pd.read_csv("Resources/charity_data.csv")
df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
df=df.drop(["EIN","NAME"],axis=1)

# %%
# Determine the number of unique values in each column.
df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
group1=df.groupby("APPLICATION_TYPE")["AFFILIATION"].count()
d1=group1.to_dict()
def cutoff(dict,cf):
    dk=dict.keys()
    dv=dict.values()
    kl=[]
    for i in dk: 
        if(dict[i]>cf):
            kl.append(i)
    return(kl)
d1
# Out:
# {'T10': 528,
#  'T12': 27,
#  'T13': 66,
#  'T14': 3,
#  'T15': 2,
#  'T17': 1,
#  'T19': 1065,
#  'T2': 16,
#  'T25': 3,
#  'T29': 2,
#  'T3': 27037,
#  'T4': 1542,
#  'T5': 1173,
#  'T6': 1216,
#  'T7': 725,
#  'T8': 737,
#  'T9': 156}

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
cf=1000

application_types_to_replace=cutoff(d1,cf)


# Replace in dataframe
for app in application_types_to_replace:
    df['APPLICATION_TYPE'] = df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
df['APPLICATION_TYPE'].value_counts()
# Out:
# Other    32033
# T8         737
# T7         725
# T10        528
# T9         156
# T13         66
# T12         27
# T2          16
# T14          3
# T25          3
# T15          2
# T29          2
# T17          1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
group2=df.groupby("CLASSIFICATION")["AFFILIATION"].count()
d2=group2.to_dict()
d2
# Out:
# {'C0': 3,
#  'C1000': 17326,
#  'C1200': 4837,
#  'C1230': 36,
#  'C1234': 2,
#  'C1235': 9,
#  'C1236': 1,
#  'C1237': 9,
#  'C1238': 10,
#  'C1240': 30,
#  'C1245': 1,
#  'C1246': 2,
#  'C1248': 1,
#  'C1250': 14,
#  'C1256': 2,
#  'C1257': 5,
#  'C1260': 3,
#  'C1267': 2,
#  'C1270': 114,
#  'C1278': 10,
#  'C1280': 50,
#  'C1283': 1,
#  'C1300': 58,
#  'C1370': 1,
#  'C1400': 34,
#  'C1500': 16,
#  'C1570': 1,
#  'C1580': 1,
#  'C1600': 5,
#  'C1700': 287,
#  'C1720': 6,
#  'C1728': 1,
#  'C1732': 1,
#  'C1800': 15,
#  'C1820': 1,
#  'C1900': 1,
#  'C2000': 6074,
#  'C2100': 1883,
#  'C2150': 1,
#  'C2170': 1,
#  'C2190': 1,
#  'C2300': 32,
#  'C2380': 1,
#  'C2400': 6,
#  'C2500': 1,
#  'C2561': 1,
#  'C2570': 1,
#  'C2600': 1,
#  'C2700': 104,
#  'C2710': 3,
#  'C2800': 95,
#  'C3000': 1918,
#  'C3200': 2,
#  'C3700': 1,
#  'C4000': 194,
#  'C4100': 6,
#  'C4120': 1,
#  'C4200': 1,
#  'C4500': 1,
#  'C5000': 116,
#  'C5200': 1,
#  'C6000': 15,
#  'C6100': 1,
#  'C7000': 777,
#  'C7100': 75,
#  'C7120': 18,
#  'C7200': 32,
#  'C7210': 7,
#  'C8000': 20,
#  'C8200': 11,
#  'C8210': 1}

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
#  YOUR CODE GOES HERE

# %%
# Choose a cutoff value and create a list of classifications to be replaced
classifications_to_replace=cutoff(d2,300)

# Replace in dataframe
for cls in classifications_to_replace:
    df['CLASSIFICATION'] = df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
df['CLASSIFICATION'].value_counts()
# Out:
# Other    32815
# C1700      287
# C4000      194
# C5000      116
# C1270      114
#          ...
# C8210        1
# C4500        1
# C2190        1
# C4200        1
# C1283        1
# Name: CLASSIFICATION, Length: 66, dtype: int64

# %%
df.dtypes
# Out:
# APPLICATION_TYPE          object
# AFFILIATION               object
# CLASSIFICATION            object
# USE_CASE                  object
# ORGANIZATION              object
# STATUS                     int64
# INCOME_AMT                object
# SPECIAL_CONSIDERATIONS    object
# ASK_AMT                    int64
# IS_SUCCESSFUL              int64
# dtype: object

# %%
# Convert categorical data to numeric with `pd.get_dummies`
df=pd.get_dummies(df)
df
# Out:
#        STATUS   ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0           1      5000              1                       0
# 1           1    108590              1                       1
# 2           1      5000              0                       1
# 3           1      6692              1                       1
# 4           1    142590              1                       1
# ...       ...       ...            ...                     ...
# 34294       1      5000              0                       1
# 34295       1      5000              0                       1
# 34296       1      5000              0                       1
# 34297       1      5000              1                       1
# 34298       1  36500179              0                       1
#
#        APPLICATION_TYPE_T10  APPLICATION_TYPE_T12  APPLICATION_TYPE_T13  \
# 0                         1                     0                     0
# 1                         0                     0                     0
# 2                         0                     0                     0
# 3                         0                     0                     0
# 4                         0                     0                     0
# ...                     ...                   ...                   ...
# 34294                     0                     0                     0
# 34295                     0                     0                     0
# 34296                     0                     0                     0
# 34297                     0                     0                     0
# 34298                     0                     0                     0
#
#        APPLICATION_TYPE_T14  APPLICATION_TYPE_T15  APPLICATION_TYPE_T17  ...  \
# 0                         0                     0                     0  ...
# 1                         0                     0                     0  ...
# 2                         0                     0                     0  ...
# 3                         0                     0                     0  ...
# 4                         0                     0                     0  ...
# ...                     ...                   ...                   ...  ...
# 34294                     0                     0                     0  ...
# 34295                     0                     0                     0  ...
# 34296                     0                     0                     0  ...
# 34297                     0                     0                     0  ...
# 34298                     0                     0                     0  ...
#
#        INCOME_AMT_1-9999  INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  \
# 0                      0                       0                         0
# 1                      1                       0                         0
# 2                      0                       0                         0
# 3                      0                       1                         0
# 4                      0                       0                         1
# ...                  ...                     ...                       ...
# 34294                  0                       0                         0
# 34295                  0                       0                         0
# 34296                  0                       0                         0
# 34297                  0                       0                         0
# 34298                  0                       0                         0
#
#        INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  \
# 0                       0                 0                       0
# 1                       0                 0                       0
# 2                       0                 0                       0
# 3                       0                 0                       0
# 4                       0                 0                       0
# ...                   ...               ...                     ...
# 34294                   0                 0                       0
# 34295                   0                 0                       0
# 34296                   0                 0                       0
# 34297                   0                 0                       0
# 34298                   0                 1                       0
#
#        INCOME_AMT_50M+  INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_N  \
# 0                    0                  0                         1
# 1                    0                  0                         1
# 2                    0                  0                         1
# 3                    0                  0                         1
# 4                    0                  0                         1
# ...                ...                ...                       ...
# 34294                0                  0                         1
# 34295                0                  0                         1
# 34296                0                  0                         1
# 34297                0                  0                         1
# 34298                0                  0                         1
#
#        SPECIAL_CONSIDERATIONS_Y
# 0                             0
# 1                             0
# 2                             0
# 3                             0
# 4                             0
# ...                         ...
# 34294                         0
# 34295                         0
# 34296                         0
# 34297                         0
# 34298                         0
#
# [34299 rows x 108 columns]

# %%
# Split our preprocessed data into our features and target arrays
y=df["IS_SUCCESSFUL"]
X=df.drop("IS_SUCCESSFUL",axis=1)

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
#  YOUR CODE GOES HERE

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=16, activation="tanh", input_dim=len(X_train_scaled[0])))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=15, activation="tanh"))

# Third hidden layer
nn.add(tf.keras.layers.Dense(units=13, activation="tanh"))
nn.add(tf.keras.layers.Dense(units=13, activation="tanh"))
nn.add(tf.keras.layers.Dense(units=10, activation="tanh"))
# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 16)                1728
# _________________________________________________________________
# dense_1 (Dense)              (None, 15)                255
# _________________________________________________________________
# dense_2 (Dense)              (None, 13)                208
# _________________________________________________________________
# dense_3 (Dense)              (None, 13)                182
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                140
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 2,524
# Trainable params: 2,524
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/30
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5985 - accuracy: 0.6979
# Epoch 2/30
# 804/804 [==============================] - 1s 951us/step - loss: 0.5858 - accuracy: 0.7113
# Epoch 3/30
# 804/804 [==============================] - 1s 978us/step - loss: 0.5836 - accuracy: 0.7138
# Epoch 4/30
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5823 - accuracy: 0.7155
# Epoch 5/30
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5814 - accuracy: 0.7157
# Epoch 6/30
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5809 - accuracy: 0.7158
# Epoch 7/30
# 804/804 [==============================] - 1s 971us/step - loss: 0.5799 - accuracy: 0.7175
# Epoch 8/30
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5795 - accuracy: 0.7172
# Epoch 9/30
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5791 - accuracy: 0.7180
# Epoch 10/30
# 804/804 [==============================] - 1s 979us/step - loss: 0.5789 - accuracy: 0.7155
# Epoch 11/30
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5785 - accuracy: 0.7165
# Epoch 12/30
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5780 - accuracy: 0.7184
# Epoch 13/30
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5776 - accuracy: 0.7180
# Epoch 14/30
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5775 - accuracy: 0.7176
# Epoch 15/30
# 804/804 [==============================] - 1s 983us/step - loss: 0.5771 - accuracy: 0.7183
# Epoch 16/30
# 804/804 [==============================] - 1s 999us/step - loss: 0.5770 - accuracy: 0.7183
# Epoch 17/30
# 804/804 [==============================] - 1s 983us/step - loss: 0.5765 - accuracy: 0.7177
# Epoch 18/30
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5767 - accuracy: 0.7171
# Epoch 19/30
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5763 - accuracy: 0.7190
# Epoch 20/30
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5760 - accuracy: 0.7192
# Epoch 21/30
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5761 - accuracy: 0.7183
# Epoch 22/30
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5758 - accuracy: 0.7191
# Epoch 23/30
# 804/804 [==============================] - 1s 996us/step - loss: 0.5759 - accuracy: 0.7197
# Epoch 24/30
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5755 - accuracy: 0.7195
# Epoch 25/30
# 804/804 [==============================] - 1s 1000us/step - loss: 0.5755 - accuracy: 0.7189
# Epoch 26/30
# 804/804 [==============================] - 1s 935us/step - loss: 0.5753 - accuracy: 0.7186
# Epoch 27/30
# 804/804 [==============================] - 1s 921us/step - loss: 0.5750 - accuracy: 0.7194
# Epoch 28/30
# 804/804 [==============================] - 1s 937us/step - loss: 0.5750 - accuracy: 0.7183
# Epoch 29/30
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5749 - accuracy: 0.7191
# Epoch 30/30
# 804/804 [==============================] - 1s 937us/step - loss: 0.5744 - accuracy: 0.7203

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5976 - accuracy: 0.7004
# Loss: 0.5976250171661377, Accuracy: 0.7004081606864929

# %%
# Export our model to HDF5 file
nn.save("nn_model.h5")
